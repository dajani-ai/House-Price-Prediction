# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('housing_cleaned.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20425    -121.09     39.48                25.0       1665.0           374.0
# 20426    -121.21     39.49                18.0        697.0           150.0
# 20427    -121.22     39.43                17.0       2254.0           485.0
# 20428    -121.32     39.43                18.0       1860.0           409.0
# 20429    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# # Transformations detected at EDA

# %%
# Log Transformation for skewed data
df['total_rooms'] = np.log(df['total_rooms'] + 1)
df['total_bedrooms'] = np.log(df['total_bedrooms'] + 1)
df['population'] = np.log(df['population'] + 1)
df['households'] = np.log(df['households'] + 1)

# %% [markdown]
# Check the skewness now

# %%
df.hist(figsize=(15,12))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# ---

# %%
# Derive new variable of (total_rooms/households)
df['household_rooms'] = df['total_rooms']/df['households']

# %% [markdown]
# Check the new feature ("household_rooms") correlation with house price ("median_house_value")

# %%
numerical_df = df.select_dtypes(include=['float64'])

plt.figure(figsize=(12, 8))
sns.heatmap(numerical_df.corr(),annot=True)

plt.show()

# %%
df.to_csv('housing_cleaned.csv', index=False)
